# %% [markdown]
# # Init

# %%
# init
from importlib import reload
from pathlib import Path
import os
import sys
import pandas as pd

sys.path.append('..')
sys.path.append("C:/Users/gonta/D/software developer/packages")
import toolsGeneral.main as tgm
import toolsPandas.helpers as tph

def reloadPckg():
    reload(tgm)
    reload(tph)

# %% [markdown]
# # Import

# %%
# import
dataDir = Path(os.path.join(os.getcwd(), '..', 'data/normalized'))
rawFiles = [f for f in dataDir.rglob('*.pkl')]
print(len(rawFiles))

df_by_cntr = {
    file.parent.name:tgm.load(str(file))
    for file in rawFiles
}
print(len(df_by_cntr))
# Out:
# 64
# 64

# %%
df_by_cntr['Greece']
# Out:
#          type        id tags.admin_level tags.parent_id  \
# 0    relation    192307                2            NaN
# 1    relation    223136                4            NaN
# 2    relation   4458374                4            NaN
# 3    relation   4477553                4            NaN
# 4    relation   4495677                4            NaN
# ..        ...       ...              ...            ...
# 584       rel  13829626                8        1827294
# 585       rel  13829627                8        1827294
# 586       rel  13829628                8        1827294
# 587       rel  13830796                8        1827377
# 588       rel  13844300                8        1827377
#
#                                              tags.name  tags.name:us  \
# 0                                                Ελλάς           NaN
# 1                                                Muğla           NaN
# 2    Αποκεντρωμένη Διοίκηση Ηπείρου - Δυτικής Μακεδ...           NaN
# 3                       Αποκεντρωμένη Διοίκηση Αττικής           NaN
# 4    Αποκεντρωμένη Διοίκηση Θεσσαλίας - Στερεάς Ελλ...           NaN
# ..                                                 ...           ...
# 584                                  Balıbey Mahallesi           NaN
# 585                                Camikebir Mahallesi           NaN
# 586                               Hacırüstem Mahallesi           NaN
# 587                                  Ulucami Mahallesi           NaN
# 588                                 Toparlar Mahallesi           NaN
#
#     tags.ISO3166-1 tags.ISO3166-2  tags.is_in:country tags.ref:nuts  \
# 0               GR            NaN                 NaN            EL
# 1              NaN          TR-48                 NaN         TR323
# 2              NaN            NaN                 NaN           NaN
# 3              NaN            NaN                 NaN           NaN
# 4              NaN            NaN                 NaN           NaN
# ..             ...            ...                 ...           ...
# 584            NaN            NaN                 NaN           NaN
# 585            NaN            NaN                 NaN           NaN
# 586            NaN            NaN                 NaN           NaN
# 587            NaN            NaN                 NaN           NaN
# 588            NaN            NaN                 NaN           NaN
#
#      tags.ref:nuts:2 tags.ref:nuts:3
# 0                NaN             NaN
# 1                NaN           TR323
# 2                NaN             NaN
# 3                NaN             NaN
# 4                NaN             NaN
# ..               ...             ...
# 584              NaN             NaN
# 585              NaN             NaN
# 586              NaN             NaN
# 587              NaN             NaN
# 588              NaN             NaN
#
# [589 rows x 12 columns]

# %% [markdown]
# # Apply fixes

# %% [markdown]
# ## 1. osm basic fix

# %%
osm_basic_test = tgm.load(os.path.join('..', 'data', 'tests results', 'osm_basic_test.pkl'))
len(osm_basic_test)
# Out:
# 64

# %%
tph.df_peek(tph.to_df(osm_basic_test).T)
# Out:
#     <div style="overflow:auto; max-height:500px; max-width:100%; border:1px solid #ccc; padding:4px;">
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>missing.name</th>
#       <th>leak</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Albania</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Algeria</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Andorra</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Australia</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Austria</th>
#       <td>[]</td>
#       <td>[52345]</td>
#     </tr>
#     <tr>
#       <th>Bangladesh</th>
#       <td>[14326679]</td>
#       <td>[3824588, 3825003, 3859335, 3921211, 3921222, 3921298, 3921322, 7318343, 9455570]</td>
#     </tr>
#     <tr>
#       <th>Belarus</th>
#       <td>[]</td>
#       <td>[59162, 59189, 59195, 59275, 59506, 59752]</td>
#     </tr>
#     <tr>
#       <th>Belgium</th>
#       <td>[]</td>
#       <td>[4217435, 7394, 7400, 7411, 7427, 7463, 7400]</td>
#     </tr>
#     <tr>
#       <th>Bhutan</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Brazil</th>
#       <td>[]</td>
#       <td>[54882, 57963, 185579, 242620, 298204, 301079, 301464, 302635, 302819, 303702, 303781, 303940, 315173, 325866, 326266, 331463, 332476, 332924, 333597, 334051, 334443, 336819, 362413, 405935, 421151, 4059665, 298424, 298446]</td>
#     </tr>
#     <tr>
#       <th>Bulgaria</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Cambodia</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Chile</th>
#       <td>[]</td>
#       <td>[153549]</td>
#     </tr>
#     <tr>
#       <th>Colombia</th>
#       <td>[14785983, 14785984, 4052088, 18995881, 19013978, 18963579, 19308206, 18999200]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Czechia</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Denmark</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Ecuador</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Estonia</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Eswatini</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>FaroeIslands</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Finland</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Georgia</th>
#       <td>[]</td>
#       <td>[1995971]</td>
#     </tr>
#     <tr>
#       <th>Germany</th>
#       <td>[]</td>
#       <td>[47826]</td>
#     </tr>
#     <tr>
#       <th>Greece</th>
#       <td>[15544495]</td>
#       <td>[223136]</td>
#     </tr>
#     <tr>
#       <th>Guinea</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Guinea-bissau</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Hungary</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Ireland</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>IsleOfMan</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Jordan</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Kyrgyzstan</th>
#       <td>[]</td>
#       <td>[178019, 178020, 178023, 178024, 178025, 178026, 1251542]</td>
#     </tr>
#     <tr>
#       <th>Laos</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Latvia</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Lebanon</th>
#       <td>[]</td>
#       <td>[184877]</td>
#     </tr>
#     <tr>
#       <th>Libya</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Lithuania</th>
#       <td>[]</td>
#       <td>[966958, 974211, 977317, 1028503, 1069509, 1076930, 1211025, 1256237, 1307305]</td>
#     </tr>
#     <tr>
#       <th>Mauritania</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Mexico</th>
#       <td>[4063348]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Moldova</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Mongolia</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Montenegro</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Myanmar</th>
#       <td>[18997125, 18996972, 18997003, 18997068, 18997125, 19097176]</td>
#       <td>[1908810, 5996473, 5996474, 5996475, 5996476, 5996477, 5996478, 5996479, 5996480, 5996481, 5996482, 5996484, 5996485, 5996486, 5996487]</td>
#     </tr>
#     <tr>
#       <th>Nepal</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>NorthKorea</th>
#       <td>[]</td>
#       <td>[356379, 356386, 356392, 356419, 356442, 356443, 356533, 356535, 356540, 3781418]</td>
#     </tr>
#     <tr>
#       <th>NorthMacedonia</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Poland</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Romania</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Russia</th>
#       <td>[]</td>
#       <td>[72169, 72181, 72639, 81995, 81996, 81997, 89331, 115106, 140292, 140294, 140295, 144763, 144764, 145194, 145195, 145454, 145729, 145730, 151225, 151228, 151233, 155262, 176095, 190090, 190911, 337422, 393980, 1574364, 2095259, 19161849, 19161871, 19161924, 19161954, 19162030, 19162067, 19162084, 19162115, 19162129]</td>
#     </tr>
#     <tr>
#       <th>Rwanda</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>SanMarino</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Senegal</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>SierraLeone</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Slovakia</th>
#       <td>[]</td>
#       <td>[388265, 388266, 388267, 388268, 388269, 388270, 388271, 388272]</td>
#     </tr>
#     <tr>
#       <th>SouthAfrica</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Sweden</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Switzerland</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Syria</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>TheGambia</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Tunisia</th>
#       <td>[]</td>
#       <td>[2060182]</td>
#     </tr>
#     <tr>
#       <th>Turkey</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Ukraine</th>
#       <td>[]</td>
#       <td>[71064, 71245, 71248, 1574364]</td>
#     </tr>
#     <tr>
#       <th>UnitedKingdom</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>VaticanCity</th>
#       <td>[]</td>
#       <td>[]</td>
#     </tr>
#     <tr>
#       <th>Vietnam</th>
#       <td>[]</td>
#       <td>[1903516]</td>
#     </tr>
#   </tbody>
# </table>
#     </div>

# %%
to_delete = []
for k,v in osm_basic_test.items():
    to_delete.extend(v['missing.name'])
    to_delete.extend(v['leak'])
len(to_delete)
# Out:
# 166

# %%
# delete missing names and leaked elements
df_by_cntr_fixed = {}
for k,df in df_by_cntr.items():
    df_by_cntr_fixed[k] = df[~df['id'].isin(to_delete)].copy()

# %%
list(map(len,[df_by_cntr['Bangladesh'],df_by_cntr_fixed['Bangladesh']]))
# Out:
# [453, 443]

# %% [markdown]
# ## 2. osm duplicates fix

# %%
data_dir = Path(os.path.join(os.getcwd(), '..', 'data/tests results/osm duplicates test'))

osm_dup_test = {
    file.parent.name:tgm.load(str(file))
    for file in data_dir.rglob('*/*.pkl')
}

# %%
to_delete_dup = []
for k,v in osm_dup_test.items():
    to_delete_dup.extend(v['duplicate.delete_elems'])
len(to_delete_dup)
# Out:
# 158

# %% [markdown]
# ## * apply

# %%
# delete duplicate elements
for k,df in df_by_cntr_fixed.items():
    df_by_cntr_fixed[k] = df[~df[['id','tags.parent_id']].apply(tuple, axis=1).isin(to_delete_dup)].copy()

# %% [markdown]
# # 3. Save!

# %%
for k,df in df_by_cntr_fixed.items():
    path = os.path.join(os.getcwd(),f'../data/fixed/{k}/{k}_fixed.pkl')
    tgm.dump(path, df)
